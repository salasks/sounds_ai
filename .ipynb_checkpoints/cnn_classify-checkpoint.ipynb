# %%
# %matplotlib inline
import glob
import os
import librosa
import numpy as np

import matplotlib.pyplot as plt
import tensorflow as tf
from data_aws.upload_data import upload, delete_dirs
import librosa.display
#### extract featurse from 
from helpers.features import * 
# MLP for Pima Indians Dataset Serialize to JSON and HDF5
from keras.models import Sequential
from keras.layers import Dense
from keras.models import model_from_json

# %%
# load json and create model
json_file = open('cnn_model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
model = model_from_json(loaded_model_json)
model.load_weights("model.weights.best_cnn.hdf5")
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_7 (Conv2D)            (None, 60, 100, 16)       80
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 30, 50, 16)        0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 30, 50, 16)        64
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 30, 50, 32)        2080
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 15, 25, 32)        0
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 15, 25, 32)        128
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 15, 25, 64)        8256
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 7, 12, 64)         0
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 7, 12, 64)         256
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 7, 12, 64)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 5376)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 500)               2688500
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 10)                5010
# =================================================================
# Total params: 2,704,374.0
# Trainable params: 2,704,150.0
# Non-trainable params: 224.0
# _________________________________________________________________

# %%
#### get features from urban8k dataset ####

tr_features = np.load('cnn_tr_features.npy')
tr_labels = np.load('cnn_tr_labels.npy')

# %%
##### Sound Classes
sound_names = ["air conditioner",
               "car horn",
               "children playing",
                "dog bark",
               "drilling",
               "engine idling", 
               "gun shot",
                "jackhammer",
               "siren",
               "street music"]

# %%
# compile the model
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', 
                  metrics=['accuracy'])

# %%
# evaluate and print test accuracy
score = model.evaluate(tr_features[13000:], tr_labels[13000:], verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.982394365358

# %%
### TODO reserve logic for training and test dataset ######

# %%
# plot a random sample of test images, their predicted labels, and ground truth

##TODO replace with actual test data from test file ####
test_features, test_labels = tr_features[13000:13026], tr_labels[13000:13026]
test_labels = [sound_names[i] for i in np.argmax(test_labels,axis=1)]
predictions = model.predict(tr_features[13000:13026])
prediction_labels = [sound_names[i] for i in np.argmax(predictions,axis=1)]
fig = plt.figure(figsize=(40, 16))

for i, idx in enumerate(np.random.choice(test_features.shape[0], size=12, replace=False)):
    ax = fig.add_subplot(3, 4, i + 1, xticks=[], yticks=[])
    librosa.display.specshow(test_features[idx,:,:,0], x_axis='time', y_axis='mel',)
    plt.xlabel('time', fontsize=30)
    plt.ylabel('Hz', fontsize=30)
    font = {"size":31}
    plt.rc('font', **font)
    pred_idx = test_labels[idx]
    true_idx = prediction_labels[idx]
    plt.tight_layout()
    ax.set_title("{} ({})".format(pred_idx, true_idx),
                  color=("green" if pred_idx == true_idx else "red"), y=1.01,)
# Out:
# 26 (12,)
